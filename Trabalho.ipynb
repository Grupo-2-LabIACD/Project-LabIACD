# %%
import os
import pandas as pd
import seaborn as sns
import numpy as np

import SimpleITK as sitk
import pydicom

import matplotlib.pyplot as plt

import pylidc as pl

# %%
df = pd.read_csv("metadata.csv")

# %%
image_path = "LIDC-IDRI/LIDC-IDRI-0001/01-01-2000-NA-NA-30178/3000566.000000-NA-03192/1-001.dcm"

# %%
#imprimir uma imagem usando SimpleITK

image = sitk.ReadImage(image_path)

img = sitk.GetArrayFromImage(image)

plt.imshow(img[0])
plt.show()

# %%
#Temos de tirar imagens que nao sejam CT

df2 = df[df['Manufacturer']=='CT']

# %%
#Path de todas as imagens CT

for i in range(1018):
    path = df2['File Location'][i]

# %%
#Converter imagens dicom para array
def convert_dicom_to_array(path):
    
    arrays = []
    
    for files in os.walk(path):
        #print(files) 
        #dá um tuplo, em que o segundo elemento do tuplo é uma lista com todos os ficheiros .dcm dentro da pasta
        
        list=files[2]
        #print(list) 
        #segundo elemento do tuplo
        
        for i in range(len(list)):
            if list[i].endswith('.dcm'):
                p = os.path.join(path,list[i])
                
                #data = pydicom.dcmread(p)
                data=sitk.ReadImage(p)
                
                #array = data.pixel_array.astype(np.int16)
                array=sitk.GetArrayFromImage(image)
                
                arrays.append(array)
                
    return arrays

# %%
for i in range(5):
    path = df2['File Location'][i]
    print(dicom_to_numpy(path))
# Out:
# [array([[-1024, -1024, -1024, ..., -1024, -1024, -1024],
#        [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#        [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#        ...,
#        [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#        [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#        [-1024, -1024, -1024, ..., -1024, -1024, -1024]], dtype=int16), array([[-1024, -1024, -1024, ..., -1024, -1024, -1024],
#        [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#        [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#        ...,
#        [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#        [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#        [-1024, -1024, -1024, ..., -1024, -1024, -1024]], dtype=int16), array([[-1024, -1024, -1024, ..., -1024, -1024, -1024],
#        [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#        [-1024, -1024, -1024, ..., -1024, -1024, -1024],
#        ...,
#        [-1024, -1024, -1024, ..., -1024, -1024, -1024],
# ...
